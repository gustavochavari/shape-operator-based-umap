# %%
import json
import pandas as pd
import numpy as np
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp
import matplotlib.pyplot as plt

# %% [markdown]
# # 1st battery of experiments

# %%
with open(r'C:\Users\User\Documents\Doutorado\shape-operator-based-umap\resultados_umap.json', 'r') as file:
    results = json.load(file)

rows = []

for dataset_name, methods in results.items():
    for method, values in methods.items():
        rows.append([dataset_name, method,
            values["Silhouette"],
            values["Calinski_Harabasz"],
            values["Davies_Bouldin"],
            values["Rand_index"],
            values["Fowlkes_Mallows"],
            values["Mutual_info"],
            values["V_measure"],
            values["Max_balanced_accuracy"],
            values["Max_kappa"],
            values["Max_precision"],
            values["Max_recall"],
            values["Max_F1_weighted"],
            values["Max_Jaccard"]])

df = pd.DataFrame(rows, columns=['Dataset', 'Method', 'SC', 'CH', 'DB','RI','FM','MI','VS','BA','KP','PR','RC','F1','JC'])

# %%
metrics = ['SC', 'CH', 'DB','RI','FM','MI','VS','BA','KP','PR','RC','F1','JC']

mask = df['Dataset'].str.contains('SHMOD')

df = df[mask].reset_index()


# Definindo os métodos e as colunas
methods = ['UMAP', 'SH-UMAP']

df
# Out:
#     level_0  index               Dataset   Method        SC           CH  \
# 0         0     18        pendigitsSHMOD     UMAP  0.371772  1566.260268
# 1         1     19        pendigitsSHMOD  SH-UMAP  0.378799  2982.672650
# 2         2     22         penguinsSHMOD     UMAP  0.308437    85.930650
# 3         3     23         penguinsSHMOD  SH-UMAP  0.138686     4.642362
# 4         4     24   mfeat-karhunenSHMOD     UMAP  0.354993  1618.799738
# 5         5     25   mfeat-karhunenSHMOD  SH-UMAP  0.266531  1331.549190
# 6         6     26          semeionSHMOD     UMAP  0.182420   593.268365
# 7         7     27          semeionSHMOD  SH-UMAP  0.182420   593.268365
# 8         8     28           cnae-9SHMOD     UMAP  0.209989   477.217258
# 9         9     29           cnae-9SHMOD  SH-UMAP  0.223734   448.290337
# 10       10     30        mnist_784SHMOD     UMAP  0.150022  1691.758866
# 11       11     31        mnist_784SHMOD  SH-UMAP  0.150022  1691.758866
# 12       12     32   Olivetti_FacesSHMOD     UMAP -0.420504     1.561973
# 13       13     33   Olivetti_FacesSHMOD  SH-UMAP -0.372078     1.341158
# 14       14     34  AP_Breast_ColonSHMOD     UMAP  0.479037   856.470821
# 15       15     35  AP_Breast_ColonSHMOD  SH-UMAP  0.479037   856.470821
#
#            DB        RI        FM        MI        VS        BA        KP  \
# 0    1.895324  0.945358  0.736855  1.804388  0.789967  0.922788  0.913320
# 1    2.123980  0.950622  0.759130  1.835504  0.801791  0.929487  0.920870
# 2    2.725442  0.738847  0.631840  0.485857  0.457332  0.994624  0.990848
# 3   15.857242  0.611143  0.480829  0.323093  0.312915  0.994624  0.990848
# 4    1.918993  0.948829  0.743939  1.777314  0.772503  0.878000  0.864444
# 5    2.244361  0.920905  0.612329  1.569626  0.685057  0.875000  0.861111
# 6    2.250088  0.907247  0.545960  1.377994  0.601868  0.787025  0.764386
# 7    2.250088  0.907247  0.545960  1.377994  0.601868  0.787025  0.764386
# 8    1.704067  0.894530  0.532081  1.256980  0.574662  0.729630  0.695833
# 9    1.640950  0.892510  0.518302  1.239348  0.565529  0.751852  0.720833
# 10  23.112848  0.890868  0.457609  1.211413  0.526984  0.734856  0.712083
# 11  23.112848  0.890868  0.457609  1.211413  0.526984  0.734856  0.712083
# 12  24.938477  0.933346  0.058310  1.440224  0.411725  0.075000  0.051282
# 13  23.796508  0.926917  0.067761  1.414071  0.408302  0.085000  0.061538
# 14   0.738514  0.807121  0.807983  0.349333  0.506195  0.919072  0.839629
# 15   0.738514  0.807121  0.807983  0.349333  0.506195  0.919072  0.839629
#
#           PR        RC        F1        JC
# 0   0.923036  0.922000  0.921471  0.859050
# 1   0.929629  0.928800  0.928590  0.871410
# 2   0.994262  0.994186  0.994181  0.988448
# 3   0.994262  0.994186  0.994181  0.988448
# 4   0.884630  0.878000  0.878563  0.794003
# 5   0.880853  0.875000  0.876557  0.795978
# 6   0.793981  0.787955  0.783668  0.659039
# 7   0.793981  0.787955  0.783668  0.659039
# 8   0.767793  0.729630  0.733052  0.606341
# 9   0.784703  0.751852  0.757018  0.634289
# 10  0.742428  0.741200  0.733901  0.600225
# 11  0.742428  0.741200  0.733901  0.600225
# 12  0.066071  0.075000  0.067684  0.039709
# 13  0.106003  0.085000  0.081734  0.047500
# 14  0.920649  0.920635  0.920557  0.852912
# 15  0.920649  0.920635  0.920557  0.852912

# %%
statistics = []

# Iterando sobre todas as combinações de métricas e métodos
for metric in metrics:
    if '_norm' not in df['Dataset'].unique():
        kiso_data = df[df['Method'] == 'K-UMAP'][metric]
        raw_data = df[df['Method'] == 'UMAP (Euclidean)'][metric]
    for method in methods:
        if method != 'K-UMAP' and method != "RAW":  # Comparar com KISOMAP
            other_data = df[df['Method'] == method][metric]
            if len(kiso_data) == len(other_data):  # Certificar-se de que temos o mesmo número de amostras
                # Realizando os testes
                stat, p_value = friedmanchisquare(raw_data, kiso_data, other_data)
                p_values_nemenyi = sp.posthoc_nemenyi_friedman(np.array([raw_data, kiso_data, other_data]).T)
                
                # Armazenando os resultados
                statistics.append({
                    'Metric': metric,
                    'Method': method,
                    'Stat': stat,
                    'P-Value Friedman': p_value,
                    # Esse aqui é o valor do teste do KISOMAP vs. (method)
                    'P-Value Nemenyi': p_values_nemenyi[0][2]
                })

            else:
                print(f'Número de amostras não corresponde entre KISOMAP e {method} para a métrica {metric}')

results_df = pd.DataFrame(statistics)

results_df['Test Friedman'] = results_df['P-Value Friedman'].apply(lambda x: 1 if x < 0.05 else 0)
results_df['Stat'] = results_df['Stat'].apply(lambda x: f"{x:.3f}")
results_df['Test Nemenyi'] = results_df['P-Value Nemenyi'].apply(lambda x: 1 if x < 0.05 else 0)
results_df['P-Value Friedman'] = results_df['P-Value Friedman'].apply(lambda x: f"{x:.3f}")
results_df['P-Value Nemenyi'] = results_df['P-Value Nemenyi'].apply(lambda x: f"{x:.3f}")

results_df = results_df.drop('Stat',axis=1)
# Out:
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica SC
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica SC
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica CH
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica CH
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica DB
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica DB
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica RI
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica RI
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica FM
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica FM
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica MI
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica MI
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica VS
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica VS
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica BA
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica BA
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica KP
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica KP
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica PR
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica PR
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica RC
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica RC
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica F1
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica F1
# Número de amostras não corresponde entre KISOMAP e UMAP para a métrica JC
# Número de amostras não corresponde entre KISOMAP e SH-UMAP para a métrica JC
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 31
#      27                 print(f'Número de amostras não corresponde entre KISOMAP e {method} para a métrica {metric}')
#      29 results_df = pd.DataFrame(statistics)
# ---> 31 results_df['Test Friedman'] = results_df['P-Value Friedman'].apply(lambda x: 1 if x < 0.05 else 0)
#      32 results_df['Stat'] = results_df['Stat'].apply(lambda x: f"{x:.3f}")
#      33 results_df['Test Nemenyi'] = results_df['P-Value Nemenyi'].apply(lambda x: 1 if x < 0.05 else 0)
#
# File c:\Users\User\Documents\Doutorado\shape-operator-based-umap\.venv\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\User\Documents\Doutorado\shape-operator-based-umap\.venv\lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'P-Value Friedman'

# %%
results_df[['Method','Metric','P-Value Friedman','P-Value Nemenyi','Test Friedman','Test Nemenyi']].sort_values(['Method','Metric'])
# Out:
#                  Method Metric P-Value Friedman P-Value Nemenyi  \
# 6                ISOMAP     CH            0.000           0.006
# 30               ISOMAP     DB            0.000           0.000
# 12               ISOMAP     FM            0.001           0.949
# 0                ISOMAP     RI            0.000           0.852
# 24               ISOMAP     SS            0.000           0.001
# 18               ISOMAP     VS            0.000           0.997
# 7            Kernel PCA     CH            0.000           0.009
# 31           Kernel PCA     DB            0.000           0.000
# 13           Kernel PCA     FM            0.000           0.987
# 1            Kernel PCA     RI            0.000           0.307
# 25           Kernel PCA     SS            0.000           0.009
# 19           Kernel PCA     VS            0.000           0.237
# 8                   LLE     CH            0.000           0.949
# 32                  LLE     DB            0.156           0.347
# 14                  LLE     FM            0.001           0.624
# 2                   LLE     RI            0.000           0.389
# 26                  LLE     SS            0.000           0.078
# 20                  LLE     VS            0.000           0.575
# 9   Laplacian Eigenmaps     CH            0.000           0.078
# 33  Laplacian Eigenmaps     DB            0.013           0.009
# 15  Laplacian Eigenmaps     FM            0.007           0.111
# 3   Laplacian Eigenmaps     RI            0.001           0.206
# 27  Laplacian Eigenmaps     SS            0.000           0.000
# 21  Laplacian Eigenmaps     VS            0.002           0.178
# 11                 UMAP     CH            0.000           0.000
# 35                 UMAP     DB            0.000           0.000
# 17                 UMAP     FM            0.001           0.811
# 5                  UMAP     RI            0.000           0.389
# 29                 UMAP     SS            0.000           0.000
# 23                 UMAP     VS            0.003           0.767
# 10                t-SNE     CH            0.000           0.000
# 34                t-SNE     DB            0.000           0.000
# 16                t-SNE     FM            0.000           0.987
# 4                 t-SNE     RI            0.000           0.178
# 28                t-SNE     SS            0.000           0.003
# 22                t-SNE     VS            0.000           0.178
#
#     Test Friedman  Test Nemenyi
# 6               1             1
# 30              1             1
# 12              1             0
# 0               1             0
# 24              1             1
# 18              1             0
# 7               1             1
# 31              1             1
# 13              1             0
# 1               1             0
# 25              1             1
# 19              1             0
# 8               1             0
# 32              0             0
# 14              1             0
# 2               1             0
# 26              1             0
# 20              1             0
# 9               1             0
# 33              1             1
# 15              1             0
# 3               1             0
# 27              1             1
# 21              1             0
# 11              1             1
# 35              1             1
# 17              1             0
# 5               1             0
# 29              1             1
# 23              1             0
# 10              1             1
# 34              1             1
# 16              1             0
# 4               1             0
# 28              1             1
# 22              1             0

# %%
###### Exportar tabela em latex
latex_code = results_df[['Method','Metric','P-Value Friedman','P-Value Nemenyi','Test Friedman','Test Nemenyi']].sort_values(['Method','Metric']).to_latex(index=False)

print(latex_code)
# Out:
# \begin{tabular}{llllrr}
# \toprule
#              Method & Metric & P-Value Friedman & P-Value Nemenyi &  Test Friedman &  Test Nemenyi \\
# \midrule
#              ISOMAP &     CH &            0.000 &           0.006 &              1 &             1 \\
#              ISOMAP &     DB &            0.000 &           0.000 &              1 &             1 \\
#              ISOMAP &     FM &            0.001 &           0.949 &              1 &             0 \\
#              ISOMAP &     RI &            0.000 &           0.852 &              1 &             0 \\
#              ISOMAP &     SS &            0.000 &           0.001 &              1 &             1 \\
#              ISOMAP &     VS &            0.000 &           0.997 &              1 &             0 \\
#          Kernel PCA &     CH &            0.000 &           0.009 &              1 &             1 \\
#          Kernel PCA &     DB &            0.000 &           0.000 &              1 &             1 \\
#          Kernel PCA &     FM &            0.000 &           0.987 &              1 &             0 \\
#          Kernel PCA &     RI &            0.000 &           0.307 &              1 &             0 \\
#          Kernel PCA &     SS &            0.000 &           0.009 &              1 &             1 \\
#          Kernel PCA &     VS &            0.000 &           0.237 &              1 &             0 \\
#                 LLE &     CH &            0.000 &           0.949 &              1 &             0 \\
#                 LLE &     DB &            0.156 &           0.347 &              0 &             0 \\
#                 LLE &     FM &            0.001 &           0.624 &              1 &             0 \\
#                 LLE &     RI &            0.000 &           0.389 &              1 &             0 \\
#                 LLE &     SS &            0.000 &           0.078 &              1 &             0 \\
#                 LLE &     VS &            0.000 &           0.575 &              1 &             0 \\
# Laplacian Eigenmaps &     CH &            0.000 &           0.078 &              1 &             0 \\
# Laplacian Eigenmaps &     DB &            0.013 &           0.009 &              1 &             1 \\
# Laplacian Eigenmaps &     FM &            0.007 &           0.111 &              1 &             0 \\
# Laplacian Eigenmaps &     RI &            0.001 &           0.206 &              1 &             0 \\
# Laplacian Eigenmaps &     SS &            0.000 &           0.000 &              1 &             1 \\
# Laplacian Eigenmaps &     VS &            0.002 &           0.178 &              1 &             0 \\
#                UMAP &     CH &            0.000 &           0.000 &              1 &             1 \\
#                UMAP &     DB &            0.000 &           0.000 &              1 &             1 \\
#                UMAP &     FM &            0.001 &           0.811 &              1 &             0 \\
#                UMAP &     RI &            0.000 &           0.389 &              1 &             0 \\
#                UMAP &     SS &            0.000 &           0.000 &              1 &             1 \\
#                UMAP &     VS &            0.003 &           0.767 &              1 &             0 \\
#               t-SNE &     CH &            0.000 &           0.000 &              1 &             1 \\
#               t-SNE &     DB &            0.000 &           0.000 &              1 &             1 \\
#               t-SNE &     FM &            0.000 &           0.987 &              1 &             0 \\
#               t-SNE &     RI &            0.000 &           0.178 &              1 &             0 \\
#               t-SNE &     SS &            0.000 &           0.003 &              1 &             1 \\
#               t-SNE &     VS &            0.000 &           0.178 &              1 &             0 \\
# \bottomrule
# \end{tabular}
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_5720\1937461386.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_code = results_df[['Method','Metric','P-Value Friedman','P-Value Nemenyi','Test Friedman','Test Nemenyi']].sort_values(['Method','Metric']).to_latex(index=False)

# %%
df_melted = pd.melt(df, id_vars=['Dataset', 'Method'], 
                    value_vars=metrics,
                    var_name='metric', value_name='value')

# Pivotando para criar uma tabela com subcolunas para cada métrica e método
df_pivot = df_melted.pivot_table(index='Dataset', 
                                 columns=['metric', 'Method'], 
                                 values='value')

df_pivot = df_pivot.swaplevel(i=0, j=1, axis=1)


df_pivot = df_pivot.sort_index(axis=1)


# 1. Stack the DataFrame to bring metrics into rows
df_stacked = df_pivot.stack(level=0)  # Stack the 'metric' level

# 2. Unstack 'Method' to bring UMAP and SH-UMAP side by side per metric
df_restructured = df_stacked.unstack(level='Method')

# 3. Reorder columns to have UMAP and SH-UMAP grouped per metric
df_restructured = df_restructured.sort_index(axis=1, level=0)

# 4. Reset index to make 'Dataset' a column (optional)
df_restructured = df_restructured.reset_index()

# 5. Round values (optional)
df_restructured = df_restructured.round(3)

# Separe as colunas numéricas (com índice MultiIndex) e as não numéricas (como 'Dataset')
numeric_cols = df_restructured.loc[:, df_restructured.columns.to_flat_index().str[0] != 'Dataset']
other_cols = df_restructured.loc[:, df_restructured.columns.to_flat_index().str[0] == 'Dataset']

# Defina a função de destaque como antes
def highlight_max_per_group(row):
    styles = [''] * len(row)
    metrics = row.index.get_level_values(0).unique()

    for metric in metrics:
        mask = row.index.get_level_values(0) == metric
        values = row[mask]

        if values.isnull().all():
            continue

        max_idx = values.astype(float).idxmax()
        for i, (idx, val) in enumerate(row.items()):
            if idx == max_idx:
                styles[i] = 'background-color: yellow; font-weight: bold'
    return styles

# Aplique o estilo apenas nas colunas numéricas
styled_numeric = numeric_cols.style.apply(highlight_max_per_group, axis=1)

# Se quiser juntar novamente com a coluna 'Dataset' para exibir
styled_df = pd.concat([other_cols, styled_numeric.data], axis=1)

styled_numeric
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15784\1450822902.py:17: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked = df_pivot.stack(level=0)  # Stack the 'metric' level
# <style type="text/css">
# #T_920c1_row0_col0, #T_920c1_row0_col2, #T_920c1_row0_col4, #T_920c1_row0_col6, #T_920c1_row0_col8, #T_920c1_row0_col10, #T_920c1_row0_col12, #T_920c1_row1_col1, #T_920c1_row1_col3, #T_920c1_row1_col4, #T_920c1_row1_col7, #T_920c1_row1_col9, #T_920c1_row1_col10, #T_920c1_row1_col13, #T_920c1_row2_col1, #T_920c1_row2_col3, #T_920c1_row2_col5, #T_920c1_row2_col7, #T_920c1_row2_col9, #T_920c1_row2_col10, #T_920c1_row2_col13, #T_920c1_row3_col1, #T_920c1_row3_col2, #T_920c1_row3_col5, #T_920c1_row3_col7, #T_920c1_row3_col9, #T_920c1_row3_col11, #T_920c1_row3_col13, #T_920c1_row4_col0, #T_920c1_row4_col2, #T_920c1_row4_col4, #T_920c1_row4_col6, #T_920c1_row4_col8, #T_920c1_row4_col10, #T_920c1_row4_col12, #T_920c1_row5_col0, #T_920c1_row5_col2, #T_920c1_row5_col4, #T_920c1_row5_col6, #T_920c1_row5_col8, #T_920c1_row5_col10, #T_920c1_row5_col12, #T_920c1_row6_col1, #T_920c1_row6_col2, #T_920c1_row6_col5, #T_920c1_row6_col7, #T_920c1_row6_col9, #T_920c1_row6_col11, #T_920c1_row6_col13, #T_920c1_row7_col0, #T_920c1_row7_col2, #T_920c1_row7_col4, #T_920c1_row7_col6, #T_920c1_row7_col8, #T_920c1_row7_col10, #T_920c1_row7_col12 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_920c1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th id="T_920c1_level0_col0" class="col_heading level0 col0" colspan="2">CH</th>
#       <th id="T_920c1_level0_col2" class="col_heading level0 col2" colspan="2">DB</th>
#       <th id="T_920c1_level0_col4" class="col_heading level0 col4" colspan="2">FM</th>
#       <th id="T_920c1_level0_col6" class="col_heading level0 col6" colspan="2">MI</th>
#       <th id="T_920c1_level0_col8" class="col_heading level0 col8" colspan="2">RI</th>
#       <th id="T_920c1_level0_col10" class="col_heading level0 col10" colspan="2">SC</th>
#       <th id="T_920c1_level0_col12" class="col_heading level0 col12" colspan="2">VS</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Method</th>
#       <th id="T_920c1_level1_col0" class="col_heading level1 col0" >SH-UMAP</th>
#       <th id="T_920c1_level1_col1" class="col_heading level1 col1" >UMAP</th>
#       <th id="T_920c1_level1_col2" class="col_heading level1 col2" >SH-UMAP</th>
#       <th id="T_920c1_level1_col3" class="col_heading level1 col3" >UMAP</th>
#       <th id="T_920c1_level1_col4" class="col_heading level1 col4" >SH-UMAP</th>
#       <th id="T_920c1_level1_col5" class="col_heading level1 col5" >UMAP</th>
#       <th id="T_920c1_level1_col6" class="col_heading level1 col6" >SH-UMAP</th>
#       <th id="T_920c1_level1_col7" class="col_heading level1 col7" >UMAP</th>
#       <th id="T_920c1_level1_col8" class="col_heading level1 col8" >SH-UMAP</th>
#       <th id="T_920c1_level1_col9" class="col_heading level1 col9" >UMAP</th>
#       <th id="T_920c1_level1_col10" class="col_heading level1 col10" >SH-UMAP</th>
#       <th id="T_920c1_level1_col11" class="col_heading level1 col11" >UMAP</th>
#       <th id="T_920c1_level1_col12" class="col_heading level1 col12" >SH-UMAP</th>
#       <th id="T_920c1_level1_col13" class="col_heading level1 col13" >UMAP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_920c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_920c1_row0_col0" class="data row0 col0" >856.471000</td>
#       <td id="T_920c1_row0_col1" class="data row0 col1" >856.471000</td>
#       <td id="T_920c1_row0_col2" class="data row0 col2" >0.739000</td>
#       <td id="T_920c1_row0_col3" class="data row0 col3" >0.739000</td>
#       <td id="T_920c1_row0_col4" class="data row0 col4" >0.808000</td>
#       <td id="T_920c1_row0_col5" class="data row0 col5" >0.808000</td>
#       <td id="T_920c1_row0_col6" class="data row0 col6" >0.349000</td>
#       <td id="T_920c1_row0_col7" class="data row0 col7" >0.349000</td>
#       <td id="T_920c1_row0_col8" class="data row0 col8" >0.807000</td>
#       <td id="T_920c1_row0_col9" class="data row0 col9" >0.807000</td>
#       <td id="T_920c1_row0_col10" class="data row0 col10" >0.479000</td>
#       <td id="T_920c1_row0_col11" class="data row0 col11" >0.479000</td>
#       <td id="T_920c1_row0_col12" class="data row0 col12" >0.506000</td>
#       <td id="T_920c1_row0_col13" class="data row0 col13" >0.506000</td>
#     </tr>
#     <tr>
#       <th id="T_920c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_920c1_row1_col0" class="data row1 col0" >1.341000</td>
#       <td id="T_920c1_row1_col1" class="data row1 col1" >1.562000</td>
#       <td id="T_920c1_row1_col2" class="data row1 col2" >23.797000</td>
#       <td id="T_920c1_row1_col3" class="data row1 col3" >24.938000</td>
#       <td id="T_920c1_row1_col4" class="data row1 col4" >0.068000</td>
#       <td id="T_920c1_row1_col5" class="data row1 col5" >0.058000</td>
#       <td id="T_920c1_row1_col6" class="data row1 col6" >1.414000</td>
#       <td id="T_920c1_row1_col7" class="data row1 col7" >1.440000</td>
#       <td id="T_920c1_row1_col8" class="data row1 col8" >0.927000</td>
#       <td id="T_920c1_row1_col9" class="data row1 col9" >0.933000</td>
#       <td id="T_920c1_row1_col10" class="data row1 col10" >-0.372000</td>
#       <td id="T_920c1_row1_col11" class="data row1 col11" >-0.421000</td>
#       <td id="T_920c1_row1_col12" class="data row1 col12" >0.408000</td>
#       <td id="T_920c1_row1_col13" class="data row1 col13" >0.412000</td>
#     </tr>
#     <tr>
#       <th id="T_920c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_920c1_row2_col0" class="data row2 col0" >448.290000</td>
#       <td id="T_920c1_row2_col1" class="data row2 col1" >477.217000</td>
#       <td id="T_920c1_row2_col2" class="data row2 col2" >1.641000</td>
#       <td id="T_920c1_row2_col3" class="data row2 col3" >1.704000</td>
#       <td id="T_920c1_row2_col4" class="data row2 col4" >0.518000</td>
#       <td id="T_920c1_row2_col5" class="data row2 col5" >0.532000</td>
#       <td id="T_920c1_row2_col6" class="data row2 col6" >1.239000</td>
#       <td id="T_920c1_row2_col7" class="data row2 col7" >1.257000</td>
#       <td id="T_920c1_row2_col8" class="data row2 col8" >0.893000</td>
#       <td id="T_920c1_row2_col9" class="data row2 col9" >0.895000</td>
#       <td id="T_920c1_row2_col10" class="data row2 col10" >0.224000</td>
#       <td id="T_920c1_row2_col11" class="data row2 col11" >0.210000</td>
#       <td id="T_920c1_row2_col12" class="data row2 col12" >0.566000</td>
#       <td id="T_920c1_row2_col13" class="data row2 col13" >0.575000</td>
#     </tr>
#     <tr>
#       <th id="T_920c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_920c1_row3_col0" class="data row3 col0" >1331.549000</td>
#       <td id="T_920c1_row3_col1" class="data row3 col1" >1618.800000</td>
#       <td id="T_920c1_row3_col2" class="data row3 col2" >2.244000</td>
#       <td id="T_920c1_row3_col3" class="data row3 col3" >1.919000</td>
#       <td id="T_920c1_row3_col4" class="data row3 col4" >0.612000</td>
#       <td id="T_920c1_row3_col5" class="data row3 col5" >0.744000</td>
#       <td id="T_920c1_row3_col6" class="data row3 col6" >1.570000</td>
#       <td id="T_920c1_row3_col7" class="data row3 col7" >1.777000</td>
#       <td id="T_920c1_row3_col8" class="data row3 col8" >0.921000</td>
#       <td id="T_920c1_row3_col9" class="data row3 col9" >0.949000</td>
#       <td id="T_920c1_row3_col10" class="data row3 col10" >0.267000</td>
#       <td id="T_920c1_row3_col11" class="data row3 col11" >0.355000</td>
#       <td id="T_920c1_row3_col12" class="data row3 col12" >0.685000</td>
#       <td id="T_920c1_row3_col13" class="data row3 col13" >0.773000</td>
#     </tr>
#     <tr>
#       <th id="T_920c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_920c1_row4_col0" class="data row4 col0" >1691.759000</td>
#       <td id="T_920c1_row4_col1" class="data row4 col1" >1691.759000</td>
#       <td id="T_920c1_row4_col2" class="data row4 col2" >23.113000</td>
#       <td id="T_920c1_row4_col3" class="data row4 col3" >23.113000</td>
#       <td id="T_920c1_row4_col4" class="data row4 col4" >0.458000</td>
#       <t

# %%
summary = {
    "Dataset": ["Média","Mediana","Mínimo","Máximo"],
    "ISOMAP": [np.mean(df_gmm['ISOMAP']['RI']),np.median(df_gmm['ISOMAP']['RI']),np.min(df_gmm['ISOMAP']['RI']),np.max(df_gmm['ISOMAP']['RI'])],
    "KISOMAP": [np.mean(df_gmm['KISOMAP']['RI']),np.median(df_gmm['KISOMAP']['RI']),np.min(df_gmm['KISOMAP']['RI']),np.max(df_gmm['KISOMAP']['RI'])],
    "Kernel PCA": [np.mean(df_gmm['Kernel PCA']['RI']),np.median(df_gmm['Kernel PCA']['RI']),np.min(df_gmm['Kernel PCA']['RI']),np.max(df_gmm['Kernel PCA']['RI'])],
    "LLE": [np.mean(df_gmm['LLE']['RI']),np.median(df_gmm['LLE']['RI']),np.min(df_gmm['LLE']['RI']),np.max(df_gmm['LLE']['RI'])],
    "Laplacian Eigenmaps": [np.mean(df_gmm['Laplacian Eigenmaps']['RI']),np.median(df_gmm['Laplacian Eigenmaps']['RI']),np.min(df_gmm['Laplacian Eigenmaps']['RI']),np.max(df_gmm['Laplacian Eigenmaps']['RI'])],
    "t-SNE": [np.mean(df_gmm['t-SNE']['RI']),np.median(df_gmm['t-SNE']['RI']),np.min(df_gmm['t-SNE']['RI']),np.max(df_gmm['t-SNE']['RI'])],
    "UMAP": [np.mean(df_gmm['UMAP']['RI']),np.median(df_gmm['UMAP']['RI']),np.min(df_gmm['UMAP']['RI']),np.max(df_gmm['UMAP']['RI'])]
}
df_summary = pd.DataFrame(summary)

# %%
df_summary.round(3)
# Out:
#    Dataset  ISOMAP  KISOMAP  Kernel PCA    LLE  Laplacian Eigenmaps  t-SNE  \
# 0    Média   0.764    0.840       0.626  0.740                0.721  0.799
# 1  Mediana   0.809    0.890       0.688  0.796                0.740  0.904
# 2   Mínimo   0.500    0.518       0.161  0.495                0.495  0.504
# 3   Máximo   0.965    0.967       0.915  0.971                0.967  0.981
#
#     UMAP
# 0  0.834
# 1  0.879
# 2  0.510
# 3  0.975

# %%
###### Exportar tabela em latex
latex_code = df_summary.round(3).to_latex(index=False)

print(latex_code)
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# Dataset &  ISOMAP &  KISOMAP &  Kernel PCA &   LLE &  Laplacian Eigenmaps &  t-SNE &  UMAP \\
# \midrule
#   Média &   0.764 &    0.840 &       0.626 & 0.740 &                0.721 &  0.799 & 0.834 \\
# Mediana &   0.809 &    0.890 &       0.688 & 0.796 &                0.740 &  0.904 & 0.879 \\
#  Mínimo &   0.500 &    0.518 &       0.161 & 0.495 &                0.495 &  0.504 & 0.510 \\
#  Máximo &   0.965 &    0.967 &       0.915 & 0.971 &                0.967 &  0.981 & 0.975 \\
# \bottomrule
# \end{tabular}
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_8712\3621184971.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_code = df_summary.round(3).to_latex(index=False)

# %%
metrics = ['BA','KP','PR','RC','F1','JC']

df_melted = pd.melt(df, id_vars=['Dataset', 'Method'], 
                    value_vars=metrics,
                    var_name='metric', value_name='value')

# Pivotando para criar uma tabela com subcolunas para cada métrica e método
df_pivot = df_melted.pivot_table(index='Dataset', 
                                 columns=['metric', 'Method'], 
                                 values='value')

df_pivot = df_pivot.swaplevel(i=0, j=1, axis=1)


df_pivot = df_pivot.sort_index(axis=1)


# 1. Stack the DataFrame to bring metrics into rows
df_stacked = df_pivot.stack(level=0)  # Stack the 'metric' level

# 2. Unstack 'Method' to bring UMAP and SH-UMAP side by side per metric
df_restructured = df_stacked.unstack(level='Method')

# 3. Reorder columns to have UMAP and SH-UMAP grouped per metric
df_restructured = df_restructured.sort_index(axis=1, level=0)

# 4. Reset index to make 'Dataset' a column (optional)
df_restructured = df_restructured.reset_index()

# 5. Round values (optional)
df_restructured = df_restructured.round(3)

# Separe as colunas numéricas (com índice MultiIndex) e as não numéricas (como 'Dataset')
numeric_cols = df_restructured.loc[:, df_restructured.columns.to_flat_index().str[0] != 'Dataset']
other_cols = df_restructured.loc[:, df_restructured.columns.to_flat_index().str[0] == 'Dataset']

# Defina a função de destaque como antes
def highlight_max_per_group(row):
    styles = [''] * len(row)
    metrics = ['BA','KP','PR','RC','F1','JC']

    for metric in metrics:
        mask = row.index.get_level_values(0) == metric
        values = row[mask]

        if values.isnull().all():
            continue

        max_idx = values.astype(float).idxmax()
        for i, (idx, val) in enumerate(row.items()):
            if idx == max_idx:
                styles[i] = 'font-weight: bold'
    return styles

# Aplique o estilo apenas nas colunas numéricas
styled_numeric = numeric_cols.style.apply(highlight_max_per_group, axis=1)

# Se quiser juntar novamente com a coluna 'Dataset' para exibir
styled_df = pd.concat([other_cols, styled_numeric.data], axis=1)

#styled_numeric
display(styled_numeric)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15784\3966050183.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked = df_pivot.stack(level=0)  # Stack the 'metric' level
# <style type="text/css">
# #T_0ab53_row0_col0, #T_0ab53_row0_col2, #T_0ab53_row0_col4, #T_0ab53_row0_col6, #T_0ab53_row0_col8, #T_0ab53_row0_col10, #T_0ab53_row1_col0, #T_0ab53_row1_col2, #T_0ab53_row1_col4, #T_0ab53_row1_col6, #T_0ab53_row1_col8, #T_0ab53_row1_col10, #T_0ab53_row2_col0, #T_0ab53_row2_col2, #T_0ab53_row2_col4, #T_0ab53_row2_col6, #T_0ab53_row2_col8, #T_0ab53_row2_col10, #T_0ab53_row3_col1, #T_0ab53_row3_col3, #T_0ab53_row3_col4, #T_0ab53_row3_col7, #T_0ab53_row3_col9, #T_0ab53_row3_col11, #T_0ab53_row4_col0, #T_0ab53_row4_col2, #T_0ab53_row4_col4, #T_0ab53_row4_col6, #T_0ab53_row4_col8, #T_0ab53_row4_col10, #T_0ab53_row5_col0, #T_0ab53_row5_col2, #T_0ab53_row5_col4, #T_0ab53_row5_col6, #T_0ab53_row5_col8, #T_0ab53_row5_col10, #T_0ab53_row6_col0, #T_0ab53_row6_col2, #T_0ab53_row6_col4, #T_0ab53_row6_col6, #T_0ab53_row6_col8, #T_0ab53_row6_col10, #T_0ab53_row7_col0, #T_0ab53_row7_col2, #T_0ab53_row7_col4, #T_0ab53_row7_col6, #T_0ab53_row7_col8, #T_0ab53_row7_col10 {
#   font-weight: bold;
# }
# </style>
# <table id="T_0ab53">
#   <thead>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th id="T_0ab53_level0_col0" class="col_heading level0 col0" colspan="2">BA</th>
#       <th id="T_0ab53_level0_col2" class="col_heading level0 col2" colspan="2">F1</th>
#       <th id="T_0ab53_level0_col4" class="col_heading level0 col4" colspan="2">JC</th>
#       <th id="T_0ab53_level0_col6" class="col_heading level0 col6" colspan="2">KP</th>
#       <th id="T_0ab53_level0_col8" class="col_heading level0 col8" colspan="2">PR</th>
#       <th id="T_0ab53_level0_col10" class="col_heading level0 col10" colspan="2">RC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Method</th>
#       <th id="T_0ab53_level1_col0" class="col_heading level1 col0" >SH-UMAP</th>
#       <th id="T_0ab53_level1_col1" class="col_heading level1 col1" >UMAP</th>
#       <th id="T_0ab53_level1_col2" class="col_heading level1 col2" >SH-UMAP</th>
#       <th id="T_0ab53_level1_col3" class="col_heading level1 col3" >UMAP</th>
#       <th id="T_0ab53_level1_col4" class="col_heading level1 col4" >SH-UMAP</th>
#       <th id="T_0ab53_level1_col5" class="col_heading level1 col5" >UMAP</th>
#       <th id="T_0ab53_level1_col6" class="col_heading level1 col6" >SH-UMAP</th>
#       <th id="T_0ab53_level1_col7" class="col_heading level1 col7" >UMAP</th>
#       <th id="T_0ab53_level1_col8" class="col_heading level1 col8" >SH-UMAP</th>
#       <th id="T_0ab53_level1_col9" class="col_heading level1 col9" >UMAP</th>
#       <th id="T_0ab53_level1_col10" class="col_heading level1 col10" >SH-UMAP</th>
#       <th id="T_0ab53_level1_col11" class="col_heading level1 col11" >UMAP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ab53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ab53_row0_col0" class="data row0 col0" >0.919000</td>
#       <td id="T_0ab53_row0_col1" class="data row0 col1" >0.919000</td>
#       <td id="T_0ab53_row0_col2" class="data row0 col2" >0.921000</td>
#       <td id="T_0ab53_row0_col3" class="data row0 col3" >0.921000</td>
#       <td id="T_0ab53_row0_col4" class="data row0 col4" >0.853000</td>
#       <td id="T_0ab53_row0_col5" class="data row0 col5" >0.853000</td>
#       <td id="T_0ab53_row0_col6" class="data row0 col6" >0.840000</td>
#       <td id="T_0ab53_row0_col7" class="data row0 col7" >0.840000</td>
#       <td id="T_0ab53_row0_col8" class="data row0 col8" >0.921000</td>
#       <td id="T_0ab53_row0_col9" class="data row0 col9" >0.921000</td>
#       <td id="T_0ab53_row0_col10" class="data row0 col10" >0.921000</td>
#       <td id="T_0ab53_row0_col11" class="data row0 col11" >0.921000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ab53_row1_col0" class="data row1 col0" >0.085000</td>
#       <td id="T_0ab53_row1_col1" class="data row1 col1" >0.075000</td>
#       <td id="T_0ab53_row1_col2" class="data row1 col2" >0.082000</td>
#       <td id="T_0ab53_row1_col3" class="data row1 col3" >0.068000</td>
#       <td id="T_0ab53_row1_col4" class="data row1 col4" >0.047000</td>
#       <td id="T_0ab53_row1_col5" class="data row1 col5" >0.040000</td>
#       <td id="T_0ab53_row1_col6" class="data row1 col6" >0.062000</td>
#       <td id="T_0ab53_row1_col7" class="data row1 col7" >0.051000</td>
#       <td id="T_0ab53_row1_col8" class="data row1 col8" >0.106000</td>
#       <td id="T_0ab53_row1_col9" class="data row1 col9" >0.066000</td>
#       <td id="T_0ab53_row1_col10" class="data row1 col10" >0.085000</td>
#       <td id="T_0ab53_row1_col11" class="data row1 col11" >0.075000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab53_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0ab53_row2_col0" class="data row2 col0" >0.752000</td>
#       <td id="T_0ab53_row2_col1" class="data row2 col1" >0.730000</td>
#       <td id="T_0ab53_row2_col2" class="data row2 col2" >0.757000</td>
#       <td id="T_0ab53_row2_col3" class="data row2 col3" >0.733000</td>
#       <td id="T_0ab53_row2_col4" class="data row2 col4" >0.634000</td>
#       <td id="T_0ab53_row2_col5" class="data row2 col5" >0.606000</td>
#       <td id="T_0ab53_row2_col6" class="data row2 col6" >0.721000</td>
#       <td id="T_0ab53_row2_col7" class="data row2 col7" >0.696000</td>
#       <td id="T_0ab53_row2_col8" class="data row2 col8" >0.785000</td>
#       <td id="T_0ab53_row2_col9" class="data row2 col9" >0.768000</td>
#       <td id="T_0ab53_row2_col10" class="data row2 col10" >0.752000</td>
#       <td id="T_0ab53_row2_col11" class="data row2 col11" >0.730000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab53_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0ab53_row3_col0" class="data row3 col0" >0.875000</td>
#       <td id="T_0ab53_row3_col1" class="data row3 col1" >0.878000</td>
#       <td id="T_0ab53_row3_col2" class="data row3 col2" >0.877000</td>
#       <td id="T_0ab53_row3_col3" class="data row3 col3" >0.879000</td>
#       <td id="T_0ab53_row3_col4" class="data row3 col4" >0.796000</td>
#       <td id="T_0ab53_row3_col5" class="data row3 col5" >0.794000</td>
#       <td id="T_0ab53_row3_col6" class="data row3 col6" >0.861000</td>
#       <td id="T_0ab53_row3_col7" class="data row3 col7" >0.864000</td>
#       <td id="T_0ab53_row3_col8" class="data row3 col8" >0.881000</td>
#       <td id="T_0ab53_row3_col9" class="data row3 col9" >0.885000</td>
#       <td id="T_0ab53_row3_col10" class="data row3 col10" >0.875000</td>
#       <td id="T_0ab53_row3_col11" class="data row3 col11" >0.878000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab53_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0ab53_row4_col0" class="data row4 col0" >0.735000</td>
#       <td id="T_0ab53_row4_col1" class="data row4 col1" >0.735000</td>
#       <td id="T_0ab53_row4_col2" class="data row4 col2" >0.734000</td>
#       <td id="T_0ab53_row4_col3" class="data row4 col3" >0.734000</td>
#       <td id="T_0ab53_row4_col4" class="data row4 col4" >0.600000</td>
#       <td id="T_0ab53_row4_col5" class="data row4 col5" >0.600000</td>
#       <td id="T_0ab53_row4_col6" class="data row4 col6" >0.712000</td>
#       <td id="T_0ab53_row4_col7" class="data row4 col7" >0.712000</td>
#       <td id="T_0ab53_row4_col8" class="data row4 col8" >0.742000</td>
#       <td id="T_0ab53_row4_col9" class="data row4 col9" >0.742000</td>
#       <td id="T_0ab53_row4_col10" class="data row4 col10" >0.741000</td>
#       <td id="T_0ab53_row4_col11" class="data row4 col11" >0.741000</td>
#     </tr>
#     <tr>
#       <th id="T_0ab53_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0ab53_row5_col0" class="data row5 col0" >0.929000</td>
#       <td id="T_0ab53_row5_col1" class="data row5 col1" >0.923000</td>
#       <td id="T_0ab53_row5_col2" class="data row5 col2" >0.929000</td>
#       <td id="T_0ab53_row5_col3" class="data row5 col3" >0.921000</td>
#       <td id="T_0ab53_row5_col4" class="data row5 col4" >0.871000</td>
#       <td id="T_0ab53_row5_col5" class="data row5 col5" >0.859000</td>
#       <td id="T_0ab53_row5_col6" class="data

# %%
###### Exportar tabela em latex
latex_code = styled_numeric.to_latex()

print(latex_code)
# Out:
# \begin{tabular}{lrrrrrrrrrrrr}
# metric & \multicolumn{2}{r}{BA} & \multicolumn{2}{r}{F1} & \multicolumn{2}{r}{JC} & \multicolumn{2}{r}{KP} & \multicolumn{2}{r}{PR} & \multicolumn{2}{r}{RC} \\
# Method & SH-UMAP & UMAP & SH-UMAP & UMAP & SH-UMAP & UMAP & SH-UMAP & UMAP & SH-UMAP & UMAP & SH-UMAP & UMAP \\
# 0 & \font-weightbold 0.919000 & 0.919000 & \font-weightbold 0.921000 & 0.921000 & \font-weightbold 0.853000 & 0.853000 & \font-weightbold 0.840000 & 0.840000 & \font-weightbold 0.921000 & 0.921000 & \font-weightbold 0.921000 & 0.921000 \\
# 1 & \font-weightbold 0.085000 & 0.075000 & \font-weightbold 0.082000 & 0.068000 & \font-weightbold 0.047000 & 0.040000 & \font-weightbold 0.062000 & 0.051000 & \font-weightbold 0.106000 & 0.066000 & \font-weightbold 0.085000 & 0.075000 \\
# 2 & \font-weightbold 0.752000 & 0.730000 & \font-weightbold 0.757000 & 0.733000 & \font-weightbold 0.634000 & 0.606000 & \font-weightbold 0.721000 & 0.696000 & \font-weightbold 0.785000 & 0.768000 & \font-weightbold 0.752000 & 0.730000 \\
# 3 & 0.875000 & \font-weightbold 0.878000 & 0.877000 & \font-weightbold 0.879000 & \font-weightbold 0.796000 & 0.794000 & 0.861000 & \font-weightbold 0.864000 & 0.881000 & \font-weightbold 0.885000 & 0.875000 & \font-weightbold 0.878000 \\
# 4 & \font-weightbold 0.735000 & 0.735000 & \font-weightbold 0.734000 & 0.734000 & \font-weightbold 0.600000 & 0.600000 & \font-weightbold 0.712000 & 0.712000 & \font-weightbold 0.742000 & 0.742000 & \font-weightbold 0.741000 & 0.741000 \\
# 5 & \font-weightbold 0.929000 & 0.923000 & \font-weightbold 0.929000 & 0.921000 & \font-weightbold 0.871000 & 0.859000 & \font-weightbold 0.921000 & 0.913000 & \font-weightbold 0.930000 & 0.923000 & \font-weightbold 0.929000 & 0.922000 \\
# 6 & \font-weightbold 0.995000 & 0.995000 & \font-weightbold 0.994000 & 0.994000 & \font-weightbold 0.988000 & 0.988000 & \font-weightbold 0.991000 & 0.991000 & \font-weightbold 0.994000 & 0.994000 & \font-weightbold 0.994000 & 0.994000 \\
# 7 & \font-weightbold 0.787000 & 0.787000 & \font-weightbold 0.784000 & 0.784000 & \font-weightbold 0.659000 & 0.659000 & \font-weightbold 0.764000 & 0.764000 & \font-weightbold 0.794000 & 0.794000 & \font-weightbold 0.788000 & 0.788000 \\
# \end{tabular}

# %% [markdown]
# # 2nd Battery of Experiments

# %%
# Carregar o arquivo de resultados da primeira bateria de experimentos
with open(r'C:\Users\Gustavo\Documents\Mestrado\curvature-based-isomap\results\final_dataset_results_2nd_battery.json', 'r') as file:
    results = json.load(file)

rows = []

for dataset_name, methods in results.items():
    for method, values in methods.items():
        rows.append([dataset_name, method, values[0][0], values[1][0],values[2][0],values[3][0],values[4][0],values[5][0]])

df = pd.DataFrame(rows, columns=['dataset', 'method', 'RI', 'CH','FM', 'VS', 'SS','DB'])

# %%
metrics = ["RI", "CH", "FM", "VS", "SS", "DB"]

data = []

# Iterar sobre os datasets e métodos
for dataset, methods in results.items():
    for method, values in methods.items():
        row = [dataset, method] + [value[0][1] for value in values]
        data.append(row)

columns = ["Dataset", "Method"] + metrics
df = pd.DataFrame(data, columns=columns)

# Retirando resultados normalizados, pegando apenas os valores brutos
mask = ~df['Dataset'].str.contains('_norm')

df_filtered = df[mask]

df = df_filtered

# Definindo os métodos e as colunas
methods = ['ISOMAP','KISOMAP', 'Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']
statistics = []

# Iterando sobre todas as combinações de métricas e métodos
for metric in metrics:
    if '_norm' not in df['Dataset'].unique():
        kiso_data = df[df['Method'] == 'KISOMAP'][metric]
        raw_data = df[df['Method'] == 'RAW'][metric]
    for method in methods:
        if method != 'KISOMAP' and method != "RAW":  # Comparar com KISOMAP
            other_data = df[df['Method'] == method][metric]
            if len(kiso_data) == len(other_data):  # Certificar-se de que temos o mesmo número de amostras
                # Realizando os testes
                stat, p_value = friedmanchisquare(raw_data, kiso_data, other_data)
                p_values_nemenyi = sp.posthoc_nemenyi_friedman(np.array([raw_data, kiso_data, other_data]).T)
                
                # Armazenando os resultados
                statistics.append({
                    'Metric': metric,
                    'Method': method,
                    'Stat': stat,
                    'P-Value Friedman': p_value,
                    # Esse aqui é o valor do teste do KISOMAP vs. (method)
                    'P-Value Nemenyi': p_values_nemenyi[0][2]
                })

            else:
                print(f'Número de amostras não corresponde entre KISOMAP e {method} para a métrica {metric}')

results_df = pd.DataFrame(statistics)

results_df['Test Friedman'] = results_df['P-Value Friedman'].apply(lambda x: 1 if x < 0.05 else 0)
results_df['Stat'] = results_df['Stat'].apply(lambda x: f"{x:.3f}")
results_df['Test Nemenyi'] = results_df['P-Value Nemenyi'].apply(lambda x: 1 if x < 0.05 else 0)
results_df['P-Value Friedman'] = results_df['P-Value Friedman'].apply(lambda x: f"{x:.3f}")
results_df['P-Value Nemenyi'] = results_df['P-Value Nemenyi'].apply(lambda x: f"{x:.3f}")

results_df = results_df.drop('Stat', axis=1)

# %%
results_df
# Out:
#    Metric               Method P-Value Friedman P-Value Nemenyi  \
# 0      RI               ISOMAP            0.000           0.645
# 1      RI           Kernel PCA            0.000           0.272
# 2      RI                  LLE            0.000           0.542
# 3      RI  Laplacian Eigenmaps            0.000           0.352
# 4      RI                t-SNE            0.003           0.088
# 5      RI                 UMAP            0.002           0.004
# 6      CH               ISOMAP            0.000           0.006
# 7      CH           Kernel PCA            0.000           0.016
# 8      CH                  LLE            0.000           0.492
# 9      CH  Laplacian Eigenmaps            0.000           0.060
# 10     CH                t-SNE            0.000           0.000
# 11     CH                 UMAP            0.000           0.000
# 12     FM               ISOMAP            0.000           0.793
# 13     FM           Kernel PCA            0.001           0.878
# 14     FM                  LLE            0.003           0.944
# 15     FM  Laplacian Eigenmaps            0.001           0.986
# 16     FM                t-SNE            0.008           0.026
# 17     FM                 UMAP            0.001           0.002
# 18     VS               ISOMAP            0.000           0.986
# 19     VS           Kernel PCA            0.000           0.040
# 20     VS                  LLE            0.000           0.396
# 21     VS  Laplacian Eigenmaps            0.001           0.878
# 22     VS                t-SNE            0.006           0.060
# 23     VS                 UMAP            0.000           0.001
# 24     SS               ISOMAP            0.000           0.010
# 25     SS           Kernel PCA            0.000           0.001
# 26     SS                  LLE            0.000           0.126
# 27     SS  Laplacian Eigenmaps            0.000           0.000
# 28     SS                t-SNE            0.000           0.016
# 29     SS                 UMAP            0.000           0.000
# 30     DB               ISOMAP            0.000           0.000
# 31     DB           Kernel PCA            0.000           0.000
# 32     DB                  LLE            0.001           0.016
# 33     DB  Laplacian Eigenmaps            0.002           0.002
# 34     DB                t-SNE            0.000           0.000
# 35     DB                 UMAP            0.000           0.000
#
#     Test Friedman  Test Nemenyi
# 0               1             0
# 1               1             0
# 2               1             0
# 3               1             0
# 4               1             0
# 5               1             1
# 6               1             1
# 7               1             1
# 8               1             0
# 9               1             0
# 10              1             1
# 11              1             1
# 12              1             0
# 13              1             0
# 14              1             0
# 15              1             0
# 16              1             1
# 17              1             1
# 18              1             0
# 19              1             1
# 20              1             0
# 21              1             0
# 22              1             0
# 23              1             1
# 24              1             1
# 25              1             1
# 26              1             0
# 27              1             1
# 28              1             1
# 29              1             1
# 30              1             1
# 31              1             1
# 32              1             1
# 33              1             1
# 34              1             1
# 35              1             1

# %%
###### Exportar tabela em latex
latex_code = results_df[['Method','Metric','P-Value Friedman','P-Value Nemenyi','Test Friedman','Test Nemenyi']].sort_values(['Method','Metric']).to_latex(index=False)

print(latex_code)
# Out:
# \begin{tabular}{llllrr}
# \toprule
#              Method & Metric & P-Value Friedman & P-Value Nemenyi &  Test Friedman &  Test Nemenyi \\
# \midrule
#              ISOMAP &     CH &            0.000 &           0.006 &              1 &             1 \\
#              ISOMAP &     DB &            0.000 &           0.000 &              1 &             1 \\
#              ISOMAP &     FM &            0.000 &           0.793 &              1 &             0 \\
#              ISOMAP &     RI &            0.000 &           0.645 &              1 &             0 \\
#              ISOMAP &     SS &            0.000 &           0.010 &              1 &             1 \\
#              ISOMAP &     VS &            0.000 &           0.986 &              1 &             0 \\
#          Kernel PCA &     CH &            0.000 &           0.016 &              1 &             1 \\
#          Kernel PCA &     DB &            0.000 &           0.000 &              1 &             1 \\
#          Kernel PCA &     FM &            0.001 &           0.878 &              1 &             0 \\
#          Kernel PCA &     RI &            0.000 &           0.272 &              1 &             0 \\
#          Kernel PCA &     SS &            0.000 &           0.001 &              1 &             1 \\
#          Kernel PCA &     VS &            0.000 &           0.040 &              1 &             1 \\
#                 LLE &     CH &            0.000 &           0.492 &              1 &             0 \\
#                 LLE &     DB &            0.001 &           0.016 &              1 &             1 \\
#                 LLE &     FM &            0.003 &           0.944 &              1 &             0 \\
#                 LLE &     RI &            0.000 &           0.542 &              1 &             0 \\
#                 LLE &     SS &            0.000 &           0.126 &              1 &             0 \\
#                 LLE &     VS &            0.000 &           0.396 &              1 &             0 \\
# Laplacian Eigenmaps &     CH &            0.000 &           0.060 &              1 &             0 \\
# Laplacian Eigenmaps &     DB &            0.002 &           0.002 &              1 &             1 \\
# Laplacian Eigenmaps &     FM &            0.001 &           0.986 &              1 &             0 \\
# Laplacian Eigenmaps &     RI &            0.000 &           0.352 &              1 &             0 \\
# Laplacian Eigenmaps &     SS &            0.000 &           0.000 &              1 &             1 \\
# Laplacian Eigenmaps &     VS &            0.001 &           0.878 &              1 &             0 \\
#                UMAP &     CH &            0.000 &           0.000 &              1 &             1 \\
#                UMAP &     DB &            0.000 &           0.000 &              1 &             1 \\
#                UMAP &     FM &            0.001 &           0.002 &              1 &             1 \\
#                UMAP &     RI &            0.002 &           0.004 &              1 &             1 \\
#                UMAP &     SS &            0.000 &           0.000 &              1 &             1 \\
#                UMAP &     VS &            0.000 &           0.001 &              1 &             1 \\
#               t-SNE &     CH &            0.000 &           0.000 &              1 &             1 \\
#               t-SNE &     DB &            0.000 &           0.000 &              1 &             1 \\
#               t-SNE &     FM &            0.008 &           0.026 &              1 &             1 \\
#               t-SNE &     RI &            0.003 &           0.088 &              1 &             0 \\
#               t-SNE &     SS &            0.000 &           0.016 &              1 &             1 \\
#               t-SNE &     VS &            0.006 &           0.060 &              1 &             0 \\
# \bottomrule
# \end{tabular}
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_8712\1937461386.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_code = results_df[['Method','Metric','P-Value Friedman','P-Value Nemenyi','Test Friedman','Test Nemenyi']].sort_values(['Method','Metric']).to_latex(index=False)

# %%
df_melted = pd.melt(df_filtered, id_vars=['Dataset', 'Method'], 
                    value_vars=['RI',
                                'CH',
                                'FM',
                                'VS', 
                                'SS',
                                'DB'],
                    var_name='metric', value_name='value')

# Pivotando para criar uma tabela com subcolunas para cada métrica e método
df_pivot = df_melted.pivot_table(index='Dataset', 
                                 columns=['metric', 'Method'], 
                                 values='value')

df_pivot = df_pivot.swaplevel(i=0, j=1, axis=1)

df_pivot = df_pivot.sort_index(axis=1)


df_gmm = df_pivot[['ISOMAP','KISOMAP','Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']].filter(like='SS')
df_gmm.reset_index(inplace=True)  

df_gmm.round(3)
# Out:
# Method                Dataset ISOMAP KISOMAP Kernel PCA    LLE  \
# metric                            SS      SS         SS     SS
# 0            AP_Breast_Kidney  0.449   0.423      0.978  0.546
# 1       AP_Endometrium_Breast  0.155   0.207      0.939  0.155
# 2           AP_Omentum_Kidney  0.192   0.324      0.933  0.117
# 3               AP_Ovary_Lung  0.271   0.261      0.941  0.218
# 4                     F-MNIST  0.221   0.241      0.097  0.185
# 5                       MNIST  0.121   0.216      0.139  0.082
# 6                  OVA_Uterus  0.208   0.266      0.984  0.393
# 7                  Pen-Digits  0.376   0.444      0.336  0.295
# 8                        USPS  0.207   0.284      0.420  0.121
# 9                      cnae-9  0.187   0.427      0.213  0.274
# 10                    coil-20  0.421   0.396      0.862  0.559
# 11                     eating  0.154   0.195      0.973  0.140
# 12             fri_c4_250_100  0.040   0.050      0.033  0.024
# 13                        har  0.201   0.199      0.063  0.157
# 14                   leukemia  0.437   0.548      0.952  0.330
# 15                 micro-mass  0.261   0.396      0.310  0.274
# 16                     oh5.wc  0.220   0.322      0.290  0.244
# 17             olivetti-faces  0.231   0.290      0.885  0.318
# 18                    semeion  0.204   0.254      0.378  0.097
#
# Method Laplacian Eigenmaps  t-SNE   UMAP
# metric                  SS     SS     SS
# 0                    0.543  0.514  0.664
# 1                    0.103  0.158  0.522
# 2                    0.191  0.163  0.553
# 3                    0.153  0.148  0.489
# 4                    0.358  0.243  0.463
# 5                    0.452  0.218  0.431
# 6                    0.182  0.239  0.368
# 7                    0.588  0.424  0.775
# 8                    0.164  0.566  0.661
# 9                    0.621  0.513  0.478
# 10                   0.398  0.603  0.644
# 11                   0.186 -0.014  0.450
# 12                   0.155  0.861  0.160
# 13                   0.202 -0.033  0.447
# 14                   0.445  0.481  0.484
# 15                   0.574  0.231  0.557
# 16                   0.494  0.318  0.383
# 17                   0.335  0.190  0.504
# 18                   0.421  0.248  0.495

# %%
summary = {
    "Dataset": ["Média","Mediana","Mínimo","Máximo"],
    "ISOMAP": [np.mean(df_gmm['ISOMAP']['DB']),np.median(df_gmm['ISOMAP']['DB']),np.min(df_gmm['ISOMAP']['DB']),np.max(df_gmm['ISOMAP']['DB'])],
    "KISOMAP": [np.mean(df_gmm['KISOMAP']['DB']),np.median(df_gmm['KISOMAP']['DB']),np.min(df_gmm['KISOMAP']['DB']),np.max(df_gmm['KISOMAP']['DB'])],
    "Kernel PCA": [np.mean(df_gmm['Kernel PCA']['DB']),np.median(df_gmm['Kernel PCA']['DB']),np.min(df_gmm['Kernel PCA']['DB']),np.max(df_gmm['Kernel PCA']['DB'])],
    "LLE": [np.mean(df_gmm['LLE']['DB']),np.median(df_gmm['LLE']['DB']),np.min(df_gmm['LLE']['DB']),np.max(df_gmm['LLE']['DB'])],
    "Laplacian Eigenmaps": [np.mean(df_gmm['Laplacian Eigenmaps']['DB']),np.median(df_gmm['Laplacian Eigenmaps']['DB']),np.min(df_gmm['Laplacian Eigenmaps']['DB']),np.max(df_gmm['Laplacian Eigenmaps']['DB'])],
    "t-SNE": [np.mean(df_gmm['t-SNE']['DB']),np.median(df_gmm['t-SNE']['DB']),np.min(df_gmm['t-SNE']['DB']),np.max(df_gmm['t-SNE']['DB'])],
    "UMAP": [np.mean(df_gmm['UMAP']['DB']),np.median(df_gmm['UMAP']['DB']),np.min(df_gmm['UMAP']['DB']),np.max(df_gmm['UMAP']['DB'])]
}
df_summary = pd.DataFrame(summary)

# %%
###### Exportar tabela em latex
latex_code = df_summary.round(3).to_latex(index=False)

print(latex_code)
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# Dataset &  ISOMAP &  KISOMAP &  Kernel PCA &   LLE &  Laplacian Eigenmaps &  t-SNE &  UMAP \\
# \midrule
#   Média &   1.767 &    1.762 &       1.044 & 2.131 &                1.418 &  1.699 & 0.807 \\
# Mediana &   1.511 &    1.584 &       1.197 & 1.893 &                1.004 &  1.307 & 0.807 \\
#  Mínimo &   0.880 &    0.921 &       0.012 & 0.627 &                0.416 &  0.096 & 0.333 \\
#  Máximo &   4.598 &    4.845 &       4.931 & 7.874 &                3.338 &  7.449 & 2.180 \\
# \bottomrule
# \end{tabular}
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_8712\3621184971.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_code = df_summary.round(3).to_latex(index=False)

# %%
###### Exportar tabela em latex
latex_code = df_gmm.round(3).to_latex(index=False)

print(latex_code)
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
#               Dataset & ISOMAP & KISOMAP & Kernel PCA &   LLE & Laplacian Eigenmaps & t-SNE &  UMAP \\
#                       &     DB &      DB &         DB &    DB &                  DB &    DB &    DB \\
# \midrule
#      AP\_Breast\_Kidney &  0.942 &   1.077 &      0.019 & 0.764 &               0.443 & 0.753 & 0.528 \\
# AP\_Endometrium\_Breast &  2.370 &   2.173 &      0.047 & 2.696 &               3.338 & 2.075 & 0.716 \\
#     AP\_Omentum\_Kidney &  2.328 &   1.914 &      0.078 & 2.820 &               2.373 & 2.042 & 0.996 \\
#         AP\_Ovary\_Lung &  1.511 &   1.694 &      0.044 & 3.176 &               2.648 & 2.211 & 0.807 \\
#               F-MNIST &  1.511 &   1.584 &      1.520 & 1.590 &               1.138 & 1.449 & 0.852 \\
#                 MNIST &  1.933 &   1.743 &      1.469 & 1.893 &               0.758 & 1.433 & 0.864 \\
#            OVA\_Uterus &  1.950 &   2.237 &      0.012 & 0.967 &               2.816 & 1.689 & 0.764 \\
#            Pen-Digits &  0.990 &   1.133 &      1.197 & 1.169 &               0.572 & 0.894 & 0.333 \\
#                  USPS &  1.640 &   1.830 &      2.349 & 3.064 &               2.531 & 0.642 & 0.513 \\
#                cnae-9 &  2.557 &   1.022 &      1.218 & 7.874 &               0.433 & 0.702 & 0.694 \\
#               coil-20 &  0.880 &   0.928 &      0.809 & 0.627 &               0.416 & 0.599 & 0.507 \\
#                eating &  1.742 &   2.361 &      0.022 & 1.927 &               1.880 & 4.491 & 0.856 \\
#        fri\_c4\_250\_100 &  4.598 &   4.845 &      4.931 & 3.524 &               1.504 & 0.096 & 2.180 \\
#                   har &  2.469 &   2.688 &      1.765 & 2.001 &               1.981 & 7.449 & 0.839 \\
#              leukemia &  0.923 &   0.921 &      0.055 & 1.185 &               0.912 & 0.815 & 0.823 \\
#            micro-mass &  1.480 &   1.298 &      1.350 & 0.880 &               0.574 & 1.302 & 0.618 \\
#                oh5.wc &  1.170 &   1.250 &      1.489 & 1.272 &               0.769 & 1.007 & 0.893 \\
#        olivetti-faces &  1.173 &   1.246 &      0.091 & 1.006 &               1.004 & 1.307 & 0.719 \\
#               semeion &  1.414 &   1.529 &      1.377 & 2.060 &               0.841 & 1.325 & 0.839 \\
# \bottomrule
# \end{tabular}
# C:\Users\Gustavo\AppData\Local\Temp\ipykernel_8712\1372045903.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex_code = df_gmm.round(3).to_latex(index=False)

# %% [markdown]
# # Análise gráfica dos resultados

# %%
metrics = ['RI', 'CH', 'FM', 'VS', 'SS', 'DB']
metrics_name = ['Rand Index', 'Calinski-Harabasz', 'Fowlkes-Mallows', 'V-Score', 'Silhouette Score', 'Davies-Bouldin Index']
methods = ['ISOMAP', 'KISOMAP', 'KPCA', 'LLE', 'LE', 't-SNE', 'UMAP']


df_gmm_ri = df_pivot[['ISOMAP','KISOMAP','Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']].filter(like='RI')
df_gmm_ri.reset_index(inplace=True)  

df_gmm_ch = df_pivot[['ISOMAP','KISOMAP','Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']].filter(like='CH')
df_gmm_ch.reset_index(inplace=True)  

df_gmm_fm = df_pivot[['ISOMAP','KISOMAP','Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']].filter(like='FM')
df_gmm_fm.reset_index(inplace=True)  

df_gmm_vs = df_pivot[['ISOMAP','KISOMAP','Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']].filter(like='VS')
df_gmm_vs.reset_index(inplace=True)  

df_gmm_ss = df_pivot[['ISOMAP','KISOMAP','Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']].filter(like='SS')
df_gmm_ss.reset_index(inplace=True)  


df_gmm_db = df_pivot[['ISOMAP','KISOMAP','Kernel PCA','LLE','Laplacian Eigenmaps','t-SNE','UMAP']].filter(like='DB')
df_gmm_db.reset_index(inplace=True)  

results_data = {
    'RI': [df_gmm_ri[['Dataset','ISOMAP']]['ISOMAP']['RI'],
             df_gmm_ri[['Dataset','KISOMAP']]['KISOMAP']['RI'],
             df_gmm_ri[['Dataset','Kernel PCA']]['Kernel PCA']['RI'],
             df_gmm_ri[['Dataset','LLE']]['LLE']['RI'],
             df_gmm_ri[['Dataset','Laplacian Eigenmaps']]['Laplacian Eigenmaps']['RI'],
             df_gmm_ri[['Dataset','t-SNE']]['t-SNE']['RI'],
             df_gmm_ri[['Dataset','UMAP']]['UMAP']['RI']],
    'CH': [df_gmm_ch[['Dataset','ISOMAP']]['ISOMAP']['CH'],
             df_gmm_ch[['Dataset','KISOMAP']]['KISOMAP']['CH'],
             df_gmm_ch[['Dataset','Kernel PCA']]['Kernel PCA']['CH'],
             df_gmm_ch[['Dataset','LLE']]['LLE']['CH'],
             df_gmm_ch[['Dataset','Laplacian Eigenmaps']]['Laplacian Eigenmaps']['CH'],
             df_gmm_ch[['Dataset','t-SNE']]['t-SNE']['CH'],
             df_gmm_ch[['Dataset','UMAP']]['UMAP']['CH']],
    'FM': [df_gmm_fm[['Dataset','ISOMAP']]['ISOMAP']['FM'],
             df_gmm_fm[['Dataset','KISOMAP']]['KISOMAP']['FM'],
             df_gmm_fm[['Dataset','Kernel PCA']]['Kernel PCA']['FM'],
             df_gmm_fm[['Dataset','LLE']]['LLE']['FM'],
             df_gmm_fm[['Dataset','Laplacian Eigenmaps']]['Laplacian Eigenmaps']['FM'],
             df_gmm_fm[['Dataset','t-SNE']]['t-SNE']['FM'],
             df_gmm_fm[['Dataset','UMAP']]['UMAP']['FM']],
    'VS': [df_gmm_vs[['Dataset','ISOMAP']]['ISOMAP']['VS'],
             df_gmm_vs[['Dataset','KISOMAP']]['KISOMAP']['VS'],
             df_gmm_vs[['Dataset','Kernel PCA']]['Kernel PCA']['VS'],
             df_gmm_vs[['Dataset','LLE']]['LLE']['VS'],
             df_gmm_vs[['Dataset','Laplacian Eigenmaps']]['Laplacian Eigenmaps']['VS'],
             df_gmm_vs[['Dataset','t-SNE']]['t-SNE']['VS'],
             df_gmm_vs[['Dataset','UMAP']]['UMAP']['VS']],
    'SS': [df_gmm_ss[['Dataset','ISOMAP']]['ISOMAP']['SS'],
             df_gmm_ss[['Dataset','KISOMAP']]['KISOMAP']['SS'],
             df_gmm_ss[['Dataset','Kernel PCA']]['Kernel PCA']['SS'],
             df_gmm_ss[['Dataset','LLE']]['LLE']['SS'],
             df_gmm_ss[['Dataset','Laplacian Eigenmaps']]['Laplacian Eigenmaps']['SS'],
             df_gmm_ss[['Dataset','t-SNE']]['t-SNE']['SS'],
             df_gmm_ss[['Dataset','UMAP']]['UMAP']['SS']],
    'DB': [df_gmm_db[['Dataset','ISOMAP']]['ISOMAP']['DB'],
             df_gmm_db[['Dataset','KISOMAP']]['KISOMAP']['DB'],
             df_gmm_db[['Dataset','Kernel PCA']]['Kernel PCA']['DB'],
             df_gmm_db[['Dataset','LLE']]['LLE']['DB'],
             df_gmm_db[['Dataset','Laplacian Eigenmaps']]['Laplacian Eigenmaps']['DB'],
             df_gmm_db[['Dataset','t-SNE']]['t-SNE']['DB'],
             df_gmm_db[['Dataset','UMAP']]['UMAP']['DB']]
} 

# Criando subplots para as métricas
fig, axes = plt.subplots(2, 3, figsize=(20, 10), constrained_layout=True)

# Iterando sobre as métricas e eixos para criar os gráficos
for ax, metric in zip(axes.flat, metrics):
    if metric == 'CH':
        data = results_data[metric]
        ax.boxplot(data, labels=methods)
        ax.set_ylabel(metric)
        ax.grid(axis='y', linestyle='--', alpha=0.7)
        ax.set_ylim(-100, 2000)  # Ajuste para o intervalo desejado
    else:
        data = results_data[metric]
        ax.boxplot(data, labels=methods)
        ax.set_ylabel(metric)
        ax.grid(axis='y', linestyle='--', alpha=0.7)        
    

# Exibindo os gráficos
plt.savefig('1st_battery_boxplots.png',dpi=300)
plt.show()

# %% [markdown]
# # Melhores métricas K-ISOMAP

# %%
data = [
    [6, 8, 6, 3, 8, 7],
    [5, 8, 7, 8, 8, 6],
    [4, 8, 1, 1, 8, 0],
    [9, 6, 9, 9, 7, 8],
    [6, 1, 7, 6, 1, 6],
    [10, 7, 3, 7, 6, 2],
    [7, 5, 5, 7, 6, 8],
    [1, 7, 6, 1, 2, 1],
    [6, 6, 0, 0, 6, 3],
    [5, 8, 5, 1, 8, 9],
    [6, 2, 6, 6, 2, 6],
    [8, 2, 8, 8, 7, 8],
    [0, 1, 9, 0, 1, 2],
    [8, 10, 8, 9, 2, 8],
    [6, 1, 8, 6, 8, 7],
    [1, 5, 8, 1, 8, 6],
    [7, 2, 7, 7, 6, 8],
    [6, 2, 1, 6, 2, 8],
    [2, 8, 2, 2, 5, 10],
    [2, 6, 3, 5, 6, 1],
    [1, 1, 1, 8, 1, 3],
    [6, 6, 6, 6, 7, 5],
    [0, 6, 0, 0, 6, 8],
    [2, 6, 7, 7, 6, 3],
    [7, 7, 7, 7, 7, 3],
    [7, 6, 7, 7, 6, 8],
    [6, 0, 0, 6, 1, 7],
    [1, 6, 1, 1, 6, 7],
    [1, 1, 1, 1, 1, 8],
    [7, 6, 7, 7, 6, 3],
    [0, 1, 0, 0, 1, 8],
    [4, 1, 4, 5, 1, 6],
    [6, 0, 6, 6, 10, 7],
    [2, 6, 6, 2, 6, 8],
    [5, 6, 5, 6, 6, 8],
    [0, 8, 0, 9, 8, 9],
    [1, 8, 1, 1, 8, 1],
    [1, 7, 4, 1, 7, 8],
    [0, 6, 0, 0, 6, 0],
    [0, 6, 2, 2, 6, 8]
]

columns = ['RI', 'CH', 'FM', 'VS', 'SS', 'DB']

df = pd.DataFrame(data, columns=columns)

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 5), constrained_layout=True)

for ax, metric in zip(axes.flat, columns):
    data = df[metric]

    counts, bins, patches = ax.hist(data, bins=range(12), align='left', rwidth=0.85, color='orange')
    ax.set_ylabel(metric)
    ax.set_xticks(range(12))
    ax.set_ylim(0, 20)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    for count, x in zip(counts, bins[:-1]):
        ax.text(x, count + 0.5, f"{int(count)}", ha='center', va='bottom', fontsize=8)

plt.savefig('best_metrics.png', dpi=300)

# %%
data_metrics = [
    6, 8, 6, 3, 8, 7,
    5, 8, 7, 8, 8, 6,
    4, 8, 1, 1, 8, 0,
    9, 6, 9, 9, 7, 8,
    6, 1, 7, 6, 1, 6,
    10, 7, 3, 7, 6, 2,
    7, 5, 5, 7, 6, 8,
    1, 7, 6, 1, 2, 1,
    6, 6, 0, 0, 6, 3,
    5, 8, 5, 1, 8, 9,
    6, 2, 6, 6, 2, 6,
    8, 2, 8, 8, 7, 8,
    0, 1, 9, 0, 1, 2,
    8, 10, 8, 9, 2, 8,
    6, 1, 8, 6, 8, 7,
    1, 5, 8, 1, 8, 6,
    7, 2, 7, 7, 6, 8,
    6, 2, 1, 6, 2, 8,
    2, 8, 2, 2, 5, 10,
    2, 6, 3, 5, 6, 1,
    1, 1, 1, 8, 1, 3,
    6, 6, 6, 6, 7, 5,
    0, 6, 0, 0, 6, 8,
    2, 6, 7, 7, 6, 3,
    7, 7, 7, 7, 7, 3,
    7, 6, 7, 7, 6, 8,
    6, 0, 0, 6, 1, 7,
    1, 6, 1, 1, 6, 7,
    1, 1, 1, 1, 1, 8,
    7, 6, 7, 7, 6, 3,
    0, 1, 0, 0, 1, 8,
    4, 1, 4, 5, 1, 6,
    6, 0, 6, 6, 10, 7,
    2, 6, 6, 2, 6, 8,
    5, 6, 5, 6, 6, 8,
    0, 8, 0, 9, 8, 9,
    1, 8, 1, 1, 8, 1,
    1, 7, 4, 1, 7, 8,
    0, 6, 0, 0, 6, 0,
    0, 6, 2, 2, 6, 8
]


plt.hist(data_metrics, bins=range(12), align='left',rwidth=0.9,color='orange')
plt.savefig('bars.png',dpi=1200)
plt.show()
